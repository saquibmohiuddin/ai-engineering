# %%
print("Hello world")
# Out:
# Hello world

# %%
class MyClass:
    def __init__(self, name):
        self.name = name

    def greet(self):
        return f"Hello, {self.name}!"

# %%
saquib = MyClass("Saquib")
print(saquib.greet())
# Out:
# Hello, Saquib!
