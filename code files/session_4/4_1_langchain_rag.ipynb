# %%
import getpass, os, requests

from langchain_groq import ChatGroq
from langchain_core.documents import Document

# %%
if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your GROQ API Key: ")

# %%
llm = ChatGroq(
    model="openai/gpt-oss-120b", 
    temperature=0.0, 
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
    )

# %%
resp = llm.invoke("What is the capital of France?")
print(resp.content)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ### LLM Calling with System Prompt
#
# In LangChain, we can represnt the input and output from various entitis as messages, which act as context for the models.
#
# Message types
#  - **System message** - Tells the model how to behave and provide context for interactions
#  - **Human message** - Represents user input and interactions with the model
#  - **AI message** - Responses generated by the model, including text content, tool calls, and metadata
#  - **Tool message** - Represents the outputs of tool calls

# %%
response = llm.invoke(
    [
        ("system", "You are a helpful assistant that provides information about countries and other live information. Use tools when needed."),
        ("user", "What is the capital of England, and what is the weather like in the capital of England?"),
    ],
    tools=[{"type": "browser_search"}],
)

print(response.content)
# Out:
# **Capital of England:** London — the capital and largest city of England【2†L4-L5】.
#
# **Current weather in London (Sept 1 2026):** Overcast with a high of 73 °F (22.7 °C) and a low of 55 °F (12.9 °C); no rain expected【0†L5-L9】.

# %%
WEB_URL = "https://raw.githubusercontent.com/groq-ai/langchain-groq/main/docs/examples/llm_rag_example.py"
